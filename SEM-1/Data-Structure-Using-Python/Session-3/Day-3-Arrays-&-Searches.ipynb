# %% [markdown]
# ## Array & Dynamic Array

# %% [markdown]
# **Key points**
#
# 1. Collection of  homogenous data
# 2. Fixed Size
# 3. Immutable

# %%
from array import *

a1 = array('i', [1, 2, 3, 4, 5, 6])
print(a1)
# Out:
# array('i', [1, 2, 3, 4, 5, 6])

# %%
# Retrieving each elements

for i in a1:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# Retrieve the elements with index

for i in range(len(a1)):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Key points for Lists**
#
# 1. Collection of heterogenous data
# 2. Dynamic Size
# 3. Mutable

# %%
# With List

l1 = [77, 22, 33, 66, 44]

# Retrieving each elements

for i in l1:
  print(i)
# Out:
# 77
# 22
# 33
# 66
# 44

# %% [markdown]
# ## Operations on arrays
#
# Question: Metric used for measuring rain fall: Mililitres
#
# Values stored for 5 days = [298, 305, 301, 320, 292]
#
# 1. Q1: What was the count on Day2?
#
# 2. Q2: What was thge count on Day4?
#
# 3. Q3: On which day the count was 320?
#
# 4. Q4: Print all the values?
#
# 5. Q5: Insert a value 310 at index 3?
#
# 6. Q6: Delete an element a index 2?

# %%
Rain_fall = [298, 305, 301, 320, 292]

# %%
# Q1: What was the count on Day2?

Rain_fall[1]
# Out:
# 305

# %%
# Q2: What was thge count on Day4?

Rain_fall[3]
# Out:
# 320

# %%
# Q3: On which day the count was 320?

for i in range(len(Rain_fall)):
  if Rain_fall[i] == 320:
    print("On Day:", i + 1)
# Out:
# On Day: 4

# %%
# Q4: Print all the values?

for i in Rain_fall:
  print(i)
# Out:
# 298
# 305
# 301
# 320
# 292

# %%
# Q5: Insert a value 310 at index 3?

Rain_fall.insert(3, 310)

# %%
Rain_fall
# Out:
# [298, 305, 301, 310, 320, 292]

# %%
# Q6: Delete an element a index 2?

Rain_fall.remove(301)

# %%
Rain_fall
# Out:
# [298, 305, 310, 320, 292]

# %% [markdown]
# ## linear Search
#
# Linear search is a simple search algorithm that sequentially checks each element in a list or array until a match is found or the entire list has been traversed.
#
# Steps:
#
# 1. Start from the first element.
# 2. Compare the current element with the target value.
# 3. If they match, return the index of the current element.
# 4. If they don't match, move to the next element.
# 5.Repeat steps 2-4 until the end of the list is reached or the target value is found.

# %%
# Lineaer [Sequential] Search

l1 = [5, 7, 2, 13, 10]

for i in range(len(l1)):
  if l1[i] == 13:
    print("Element found at index:", i)
# Out:
# Element found at index: 3

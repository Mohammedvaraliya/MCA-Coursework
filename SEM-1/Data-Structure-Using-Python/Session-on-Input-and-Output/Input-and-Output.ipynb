# %% [markdown]
# ### Aim:
#
# To understand and implement input and output operations in Python, including reading data from the user and displaying results on the console.
#
# ### Concept:
#
# The **input** function is used to receive data from the user, while the **print** function is used to output data to the console. Python offers flexibility for both input and output operations, allowing for formatted output and easy type conversion of input data.
#
# ### Algorithm:
#
# 1. Use the `input()` function to take user input.
# 2. Convert the input if necessary (e.g., to an integer or float).
# 3. Use the `print()` function to display the results.

# %% [markdown]
# #### Python User Input

# %%
# using input() to take user input
num = input('Enter a number: ')

print('You Entered:', num)

print('Data type of num:', type(num))
# Out:
# Enter a number: 110
# You Entered: 110
# Data type of num: <class 'str'>

# %%
num = int(input('Enter a number: '))

print('You Entered:', num)

print('Data type of num:', type(num))
# Out:
# Enter a number: 110
# You Entered: 110
# Data type of num: <class 'int'>

# %% [markdown]
# #### Python Output

# %%
print('Python is powerful')
# Out:
# Python is powerful

# %% [markdown]
# ### **Syntax of print()**
#   1. In the above code, the `print()` function is taking a single parameter.
#   2. However, the actual syntax of the print function accepts **5** parameters
#
#       ```python
#       print(object= separator= end= file= flush=)
#       ```
#
#   3. Here,
#       1. **object** - value(s) to be printed.
#       2. **sep** (optional) - allows us to separate multiple **objects** inside `print()`.
#       3. **end** (optional) - allows us to add add specific values like new line `"\n"`, tab `"\t"`.
#       4. **file** (optional) - where the values are printed. It's default value is `sys.stdout` (screen).
#       5. **flush** (optional) - Boolean specifying if the output is flushed or buffered. Default: `False`.

# %% [markdown]
# #### Python Print Statement

# %%
print('Good Morning!')
print('It is rainy today')
# Out:
# Good Morning!
# It is rainy today

# %% [markdown]
# #### Python print() with end Parameter

# %%
# print with end whitespace
print('Good Morning!', end= ' ')

print('It is rainy today')
# Out:
# Good Morning! It is rainy today

# %% [markdown]
# #### Python print() with sep parameter

# %%
print('Mohammed Varaliya', 54, 'KJSIM(MCA-FY)', sep= '. ')
# Out:
# Mohammed Varaliya. 54. KJSIM(MCA-FY)

# %% [markdown]
# #### Print Python Variables and Literals

# %%
number = -11.3

name = "Mohammed Varaliya"

# print literals
print(5)

# print variables
print(number)
print(name)
# Out:
# 5
# -11.3
# Mohammed Varaliya

# %% [markdown]
# #### Print Concatenated Strings

# %%
print('Mohammed Varaliya ' + '54.')
# Out:
# Mohammed Varaliya 54.

# %% [markdown]
# #### Output formatting

# %%
x = 5
y = 10

print('The value of x is {} and y is {}'.format(x,y))
# Out:
# The value of x is 5 and y is 10

# %% [markdown]
# # Dataset 1 retail_sales.csv

# %%
from google.colab import files
import pandas as pd

# %%
uploaded1 = files.upload()
filename1 = next(iter(uploaded1))
# Out:
#      <input type="file" id="files-10b70e34-0297-48ba-8b3a-74272872df9d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10b70e34-0297-48ba-8b3a-74272872df9d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(filename1)
# print(df.to_string())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  24-11-2023     CUST001    Male   34           Beauty
# 1               2  27-02-2023     CUST002  Female   26         Clothing
# 2               3  13-01-2023     CUST003    Male   50      Electronics
# 3               4  21-05-2023     CUST004    Male   37         Clothing
# 4               5  06-05-2023     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %% [markdown]
# ### To view the only categorical data:

# %%
df.select_dtypes(include=['object'])
# Out:
#            Date Customer ID  Gender Product Category
# 0    24-11-2023     CUST001    Male           Beauty
# 1    27-02-2023     CUST002  Female         Clothing
# 2    13-01-2023     CUST003    Male      Electronics
# 3    21-05-2023     CUST004    Male         Clothing
# 4    06-05-2023     CUST005    Male           Beauty
# ..          ...         ...     ...              ...
# 995  16-05-2023     CUST996    Male         Clothing
# 996  17-11-2023     CUST997    Male           Beauty
# 997  29-10-2023     CUST998  Female           Beauty
# 998  05-12-2023     CUST999  Female      Electronics
# 999  12-04-2023    CUST1000    Male      Electronics
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### To view the only numerical data:

# %%
df.select_dtypes(include=['number'])
# Out:
#      Transaction ID  Age  Quantity  Price per Unit  Total Amount
# 0                 1   34         3              50           150
# 1                 2   26         2             500          1000
# 2                 3   50         1              30            30
# 3                 4   37         1             500           500
# 4                 5   30         2              50           100
# ..              ...  ...       ...             ...           ...
# 995             996   62         1              50            50
# 996             997   52         3              30            90
# 997             998   23         4              25           100
# 998             999   36         3              50           150
# 999            1000   47         4              30           120
#
# [1000 rows x 5 columns]

# %% [markdown]
# ### Display first 7 rows of the "Price per Unit" values in the dataset

# %%
df["Price per Unit"].head(7)
# Out:
# 0     50
# 1    500
# 2     30
# 3    500
# 4     50
# 5     30
# 6     25
# Name: Price per Unit, dtype: int64

# %% [markdown]
# ### Display first 5 rows of the "Quantity" and "Price per Unit" values in the dataset

# %%
df[["Quantity", "Price per Unit"]].head()
# Out:
#    Quantity  Price per Unit
# 0         3              50
# 1         2             500
# 2         1              30
# 3         1             500
# 4         2              50

# %% [markdown]
# ### Display last few rows of the dataset

# %%
df.tail()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  16-05-2023     CUST996    Male   62         Clothing
# 996             997  17-11-2023     CUST997    Male   52           Beauty
# 997             998  29-10-2023     CUST998  Female   23           Beauty
# 998             999  05-12-2023     CUST999  Female   36      Electronics
# 999            1000  12-04-2023    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %% [markdown]
# ### Display last 8 rows of the dataset

# %%
df.tail(8)
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 992             993  06-02-2023     CUST993  Female   48      Electronics
# 993             994  18-12-2023     CUST994  Female   51           Beauty
# 994             995  30-04-2023     CUST995  Female   41         Clothing
# 995             996  16-05-2023     CUST996    Male   62         Clothing
# 996             997  17-11-2023     CUST997    Male   52           Beauty
# 997             998  29-10-2023     CUST998  Female   23           Beauty
# 998             999  05-12-2023     CUST999  Female   36      Electronics
# 999            1000  12-04-2023    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 992         3              50           150
# 993         2             500          1000
# 994         1              30            30
# 995         1              50            50
# 996         3              30            90
# ...

# %% [markdown]
# ### Display last 5 rows of the "" from the dataset

# %%
df[["Customer ID", "Gender", "Age"]].tail()
# Out:
#     Customer ID  Gender  Age
# 995     CUST996    Male   62
# 996     CUST997    Male   52
# 997     CUST998  Female   23
# 998     CUST999  Female   36
# 999    CUST1000    Male   47

# %% [markdown]
# ### Number of rows and columns

# %%
df.shape
# Out:
# (1000, 9)

# %% [markdown]
# ### How many columns are there in the dataset?

# %%
df.shape[1]
# Out:
# 9

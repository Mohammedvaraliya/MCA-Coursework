# %%
from google.colab import files
import pandas as pd
import warnings
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report
warnings.filterwarnings('ignore')

# %%
uploaded1 = files.upload()
filename1 = next(iter(uploaded1))
# Out:
#      <input type="file" id="files-e5876fab-5624-4e0a-a89d-cba361725593" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5876fab-5624-4e0a-a89d-cba361725593">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
prakriti_df1 = pd.read_excel(filename1)

# %%
prakriti_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Timestamp                         133 non-null    datetime64[ns]
#  1   Email Address                     133 non-null    object
#  2   Name                              131 non-null    object
#  3   Age group                         133 non-null    object
#  4   City                              133 non-null    object
#  5   Are you diabetic?                 133 non-null    object
#  6   Do you have high/low BP problem?  133 non-null    object
#  7   Skin color                        133 non-null    object
#  8   Skin texture                      133 non-null    object
#  9   Details about hair type           133 non-null    object
#  10  Texture of hair                   133 non-null    object
# ...

# %%
prakriti_df1
# Out:
#                   Timestamp                Email Address  \
# 0   2022-05-05 23:42:35.166     shwetadshirsat@gmail.com
# 1   2022-05-05 23:53:39.503       santosh.ap@somaiya.edu
# 2   2022-05-06 00:00:59.700      reddysamata75@gmail.com
# 3   2022-05-06 00:03:58.853      Sadafbano9660@gmail.com
# 4   2022-05-06 00:05:54.263          cda.achar@gmail.com
# ..                      ...                          ...
# 128 2022-05-10 21:31:30.035  sejal.shah.gandhi@gmail.com
# 129 2022-05-12 15:22:30.009        pranav.g33k@gmail.com
# 130 2022-05-15 11:18:02.607        sumagna.b@somaiya.edu
# 131 2022-05-27 05:19:49.137          krantee@somaiya.edu
# 132 2022-05-27 11:23:09.663            alkak_iom@met.edu
#
#                         Name    Age group     City Are you diabetic?  \
# 0             Shweta Shirsat  20-30 years   Mumbai                No
# 1    Santosh Ajitkumar Patil  20-30 years   Sangli                No
# 2               Samata reddy     50 above   Mumbai               Yes
# ...

# %%
uploaded2 = files.upload()
filename2 = next(iter(uploaded2))
# Out:
#      <input type="file" id="files-268d5a05-635b-4b3c-a07d-09df84fe1d39" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-268d5a05-635b-4b3c-a07d-09df84fe1d39">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
prakriti_df2 = pd.read_csv(filename2)

# %%
prakriti_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 68 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Username                          121 non-null    object
#  1   Name                              120 non-null    object
#  2   Age group                         121 non-null    object
#  3   City                              121 non-null    object
#  4   Are you diabetic?                 121 non-null    object
#  5   Do you have high/low BP problem?  121 non-null    object
#  6   Skin color                        121 non-null    float64
#  7   Skin texture                      121 non-null    float64
#  8   Details about hair type           121 non-null    float64
#  9   Texture of hair                   121 non-null    float64
#  10  My hairs are                      121 non-null    float64
# ...

# %%
prakriti_df2.describe()
# Out:
#        Skin color  Skin texture  Details about hair type  Texture of hair   \
# count  121.000000    121.000000               121.000000        121.000000
# mean     2.454545      2.355372                 2.074380          1.793388
# std      0.875595      0.835259                 0.565174          0.706132
# min      1.000000      1.000000                 1.000000          1.000000
# 25%      1.000000      2.000000                 2.000000          1.000000
# 50%      3.000000      3.000000                 2.000000          2.000000
# 75%      3.000000      3.000000                 2.000000          2.000000
# max      3.000000      3.000000                 3.000000          3.000000
#
#        My hairs are  Hair falling tendency\t      Eyes\t  \
# count    121.000000               121.000000  121.000000
# mean       1.909091                 1.859504    1.917355
# std        0.930949                 0.662140    0.770138
# min        1.000000                 1.000000    1.000000
# ...

# %%
prakriti_df2
# Out:
#                      Username                     Name    Age group    City  \
# 0    shwetadshirsat@gmail.com           Shweta Shirsat  20-30 years  Mumbai
# 1      santosh.ap@somaiya.edu  Santosh Ajitkumar Patil  20-30 years  Sangli
# 2     reddysamata75@gmail.com             Samata reddy     50 above  Mumbai
# 3     Sadafbano9660@gmail.com                    Sadaf  20-30 years  Mumbai
# 4         cda.achar@gmail.com             Chetna Achar  40-50 years  Mumbai
# ..                        ...                      ...          ...     ...
# 130                       NaN                      NaN          NaN     NaN
# 131                       NaN                      NaN          NaN     NaN
# 132                       NaN                      NaN          NaN     NaN
# 133                       NaN                      NaN          NaN     NaN
# 134                       NaN                      NaN          NaN     NaN
#
# ...

# %%
prakriti_df2.columns
# Out:
# Index(['Username', 'Name', 'Age group', 'City', 'Are you diabetic?',
#        'Do you have high/low BP problem?', 'Skin color', 'Skin texture',
#        'Details about hair type', 'Texture of hair ', 'My hairs are',
#        'Hair falling tendency\t', 'Eyes\t', 'My eyes  eye balls are',
#        'Physique\t', 'Veins\t', 'Usual body temperature \t', 'Teeth \t',
#        'Is your lips\t', 'Hands(Length)', 'Body hair\t', 'Joints\t', 'Chest\t',
#        'Tongue\t', 'Body frame (Length)\t', 'Body frame (Breadth)\t',
#        'Bodyweight changes\t', 'Style of speaking\t', 'Voice \t', 'Walk \t',
#        'Appetite \t ', 'Intensity of hunger\t', 'Favorite climate\t',
#        'Stamina\t', 'Tastes, I like most', 'Eagerness about drinking water',
#        'Frequency of liquid intake\t', 'Sleep\t', 'Quantity of sweat\t',
#        'Emotion\t', 'Intellect\t', 'Grasping\t', 'Concentration\t', 'Memory\t',
#        'Temperament\t', 'Patience\t', 'Satisfaction/content\t',
# ...

# %%
prakriti_df2 = prakriti_df2.drop(['Username', 'Name', 'Age group', 'City', 'Are you diabetic?', 'Do you have high/low BP problem?'], axis=1)

# %%
prakriti_df2.columns
# Out:
# Index(['Skin color', 'Skin texture', 'Details about hair type',
#        'Texture of hair ', 'My hairs are', 'Hair falling tendency\t', 'Eyes\t',
#        'My eyes  eye balls are', 'Physique\t', 'Veins\t',
#        'Usual body temperature \t', 'Teeth \t', 'Is your lips\t',
#        'Hands(Length)', 'Body hair\t', 'Joints\t', 'Chest\t', 'Tongue\t',
#        'Body frame (Length)\t', 'Body frame (Breadth)\t',
#        'Bodyweight changes\t', 'Style of speaking\t', 'Voice \t', 'Walk \t',
#        'Appetite \t ', 'Intensity of hunger\t', 'Favorite climate\t',
#        'Stamina\t', 'Tastes, I like most', 'Eagerness about drinking water',
#        'Frequency of liquid intake\t', 'Sleep\t', 'Quantity of sweat\t',
#        'Emotion\t', 'Intellect\t', 'Grasping\t', 'Concentration\t', 'Memory\t',
#        'Temperament\t', 'Patience\t', 'Satisfaction/content\t',
#        'While making decisions\t', 'Activities\t', 'Nature of dreams\t',
# ...

# %%
prakriti_df2
# Out:
#      Skin color  Skin texture  Details about hair type  Texture of hair   \
# 0           3.0           2.0                      2.0               3.0
# 1           3.0           3.0                      2.0               1.0
# 2           3.0           1.0                      2.0               1.0
# 3           2.0           2.0                      1.0               1.0
# 4           3.0           3.0                      1.0               2.0
# ..          ...           ...                      ...               ...
# 130         NaN           NaN                      NaN               NaN
# 131         NaN           NaN                      NaN               NaN
# 132         NaN           NaN                      NaN               NaN
# 133         NaN           NaN                      NaN               NaN
# 134         NaN           NaN                      NaN               NaN
#
#      My hairs are  Hair falling tendency\t  Eyes\t  My eyes  eye balls are  \
# ...

# %%
prakriti_df2['Prakriti'] = [
    'Pitta-Kapha', 'Vata', 'Pitta', 'Kapha', 'Pitta-Kapha', 'Pitta',
    'Kapha', 'Kapha-Pitta', 'Pitta', 'Pitta-Kapha', 'Kapha-Pitta',
    'Kapha', 'Kapha-Pitta', 'Pitta', 'Pitta', 'Kapha'
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-141782d1b3bc> in <cell line: 0>()
# ----> 1 prakriti_df2['Prakriti'] = [
#       2     'Pitta-Kapha', 'Vata', 'Pitta', 'Kapha', 'Pitta-Kapha', 'Pitta',
#       3     'Kapha', 'Kapha-Pitta', 'Pitta', 'Pitta-Kapha', 'Kapha-Pitta',
#       4     'Kapha', 'Kapha-Pitta', 'Pitta', 'Pitta', 'Kapha'
#       5 ]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
# ...

# %%
# First, create the 'Prakriti' column and initialize with NaN or empty string
prakriti_df2['Prakriti'] = ''

# Then, assign labels to the first 16 rows
prakriti_labels = [
    'Pitta-Kapha', 'Vata', 'Pitta', 'Kapha', 'Pitta-Kapha', 'Pitta',
    'Kapha', 'Kapha-Pitta', 'Pitta', 'Pitta-Kapha', 'Kapha-Pitta',
    'Kapha', 'Kapha-Pitta', 'Pitta', 'Pitta', 'Kapha'
]

for i in range(len(prakriti_labels)):
    prakriti_df2.at[i, 'Prakriti'] = prakriti_labels[i]

# %%
prakriti_df2
# Out:
#      Skin color  Skin texture  Details about hair type  Texture of hair   \
# 0           3.0           2.0                      2.0               3.0
# 1           3.0           3.0                      2.0               1.0
# 2           3.0           1.0                      2.0               1.0
# 3           2.0           2.0                      1.0               1.0
# 4           3.0           3.0                      1.0               2.0
# ..          ...           ...                      ...               ...
# 130         NaN           NaN                      NaN               NaN
# 131         NaN           NaN                      NaN               NaN
# 132         NaN           NaN                      NaN               NaN
# 133         NaN           NaN                      NaN               NaN
# 134         NaN           NaN                      NaN               NaN
#
#      My hairs are  Hair falling tendency\t  Eyes\t  My eyes  eye balls are  \
# ...

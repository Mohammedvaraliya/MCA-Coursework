# %% [markdown]
# ## Exploratory Analysis
#
#
# ### Question:
#
# Implement Subplot - Include six Different Plots init.
#
# Apply:
# 1. Line Plot
# 2. Bar chart
# 3. Scatter Plot
# 4. Area Plot
# 5. Pie Chart
# 6. Histogram

# %%
from google.colab import files
import pandas as pd

# %%
uploaded = files.upload()
titanicDataSet = next(iter(uploaded))
# Out:
#      <input type="file" id="files-672ba979-44f9-4e30-a851-fd93f2df2e0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-672ba979-44f9-4e30-a851-fd93f2df2e0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(titanicDataSet)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a 2x3 matrix of subplots
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

# 1. Line Plot - Age vs Fare using seaborn's lineplot
sns.lineplot(x=df['Age'], y=df['Fare'], ax=axs[0, 0], color='b')
axs[0, 0].set_title('Line Plot: Age vs Fare')
axs[0, 0].set_xlabel('Age')
axs[0, 0].set_ylabel('Fare')

# 2. Bar Chart - Survived by Pclass using seaborn's barplot
sns.barplot(x=pclass_survival.index, y=pclass_survival.values, ax=axs[0, 1], color='g')
axs[0, 1].set_title('Bar Chart: Survival by Pclass')
axs[0, 1].set_xlabel('Pclass')
axs[0, 1].set_ylabel('Survival Rate')

# 3. Scatter Plot - Age vs SibSp using seaborn's scatterplot
sns.scatterplot(x=df['Age'], y=df['SibSp'], ax=axs[0, 2], color='r', alpha=0.5)
axs[0, 2].set_title('Scatter Plot: Age vs SibSp')
axs[0, 2].set_xlabel('Age')
axs[0, 2].set_ylabel('SibSp')

# 4. Area Plot - Age Distribution using seaborn's lineplot with shade (area plot)
sns.lineplot(x=df['Age'], y=df['Age'], ax=axs[1, 0], color='c', alpha=0.5)
axs[1, 0].fill_between(df['Age'].dropna(), 0, df['Age'].dropna(), color='c', alpha=0.5)
axs[1, 0].set_title('Area Plot: Age Distribution')
axs[1, 0].set_xlabel('Age')
axs[1, 0].set_ylabel('Frequency')

# 5. Pie Chart - Gender Distribution using pandas' plot function
gender_counts = df['Sex'].value_counts()
axs[1, 1].pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', colors=['orange', 'lightblue'], startangle=90)
axs[1, 1].set_title('Pie Chart: Gender Distribution')

# 6. Histogram - Fare Distribution using seaborn's histplot
sns.histplot(df['Fare'].dropna(), bins=20, ax=axs[1, 2], color='purple', kde=False, edgecolor='black')
axs[1, 2].set_title('Histogram: Fare Distribution')
axs[1, 2].set_xlabel('Fare')
axs[1, 2].set_ylabel('Frequency')

plt.tight_layout()

plt.show()
